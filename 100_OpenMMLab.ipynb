# %% [markdown]
# 설명: OpenMMLab은 유명 컴퓨터 비전 알고리즘을 모아놓은 것을 취지로 하는 레포지토리이다.
# ![image.png](attachment:image.png)

# %% [markdown]
# 본인은 3D 비전을 업무로 다루고 있으므로 아래 사용법을 집중적으로 살펴볼 것이다.

# %% [markdown]
# ![image.png](attachment:image.png)
