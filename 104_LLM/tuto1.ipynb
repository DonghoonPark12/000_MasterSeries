# %% [markdown]
# #### 랭체인이란?
# - LLM 어플리케이션 개발을 위한 오픈소스 프레임워크
# - 파이썬, 자바스크립트 패키지 지원
# - 구성(Composition)과 모듈성(Modulity)에 집중
# - 출처: https://learn.deeplearning.ai/langchain

# %% [markdown]
# -----

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### LangChain: Models, Prompts and Output Parsers
#  * Direct API calls to OpenAI
#  * API calls through LangChain:
#    * Prompts
#    * Models
#    * Output parsers
