# %% [markdown]
# `torch.nn.functional.normalize(input, p=2.0, dim=1, eps=1e-12, out=None)`
# - input에 대해서 Lp 정규화를 수행
# - 입력 사이즈 (n0, ..., nk), 각 벡터 v는 아래와 같이 변형된다.
#   (벡터 절대 값으로 벡터는 나눈다.)
# - input (Tensor) – input tensor of any shape
# - p (float) – the exponent value in the norm formulation. Default: 2
# - dim (int or tuple of ints) – the dimension to reduce. Default: 1
# - eps (float) – small value to avoid division by zero. Default: 1e-12
# - out (Tensor, optional) – the output tensor. If out is used, this operation won’t be differentiable.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### `torch.nn.functional.cross_entropy vs torch.nn.CrossEntropyLoss()`
# - torch.nn.functional은 함수이고, torch.nn 은 클래스이다.
# - 둘다 같은 값을 반환한다.
# -
